# %%
#input harga awal dan persentase diskon
harga_asli = 123000

#input harga persentase diskon (%)
diskon = 23 

# Menghitung harga diskon
harga_diskon = harga_asli * diskon/100

# Menghitung harga setelah diskon
harga_setelah_diskon = harga_asli - diskon

# Menampilkan hasil
print('Harga asli: Rp {}'.format(harga_asli))
print('Diskon: 23%')
print('Harga diskon : Rp {}'.format(harga_diskon))
# Out:
# Harga asli: Rp 123000
# Diskon: 23%
# Harga diskon : Rp 28290.0
