# %%
import pandas as pd
import numpy as np


# creating a pandas series for each column
series_name = pd.Series(['pena', 'pensil'])
series_jumlah = pd.Series([5, 8])
series_harga = pd.Series([7000 , 2000])

dict_of_series = {'Nama':series_name,
                  'Jumlah':series_jumlah,
                  'Harga':series_harga}

# creating a dataframe
df_series = pd.DataFrame(dict_of_series)

total_harga_barang = ((series_jumlah[0]*series_harga[0])+ series_jumlah[1]*series_harga[1])
print(total_harga_barang)
# Out:
# 51000

# %%
print(df_series)
# Out:
#      Nama  Jumlah  Harga
# 0    pena       5   7000
# 1  pensil       8   2000
